# %%
import json
import numpy as np

file_path = "merged_map/dair_v2x_seq_vector_map.json"

with open(file_path, 'r') as json_file:
    data = json.load(json_file)

# %%
file_path = "merged_map/dair_v2x_seq_halluc_bbox_table.npy" 
npy_data = np.load(file_path)

print(npy_data[0])
# Out:
# [ 416057.54530427 4728351.72120746  416065.72299973 4728438.12577454]

# %%
file_path = "/y/minkycho/DAIR-V2X-Seq/dataset/v2x-seq-tfd/maps/yizhuang_hdmap3.json" # Enter your own path

with open(file_path, 'r') as json_file:
    data = json.load(json_file)

print(data.keys())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_2571/1772540027.py in <module>
#       1 file_path = "merged_map/yizhuang_hdmap3.json" # Enter your own path
#       2
# ----> 3 with open(file_path, 'r') as json_file:
#       4     data = json.load(json_file)
#       5
#
# FileNotFoundError: [Errno 2] No such file or directory: 'merged_map/yizhuang_hdmap3.json'

# %%
data['CROSSWALK'] # show polygon coordinates
# Out:
# {'1489378162': {'polygon': ['(417268.436587, 4731303.761017)',
#    '(417270.536596, 4731300.385756)',
#    '(417288.920727, 4731311.759854)',
#    '(417286.747290, 4731315.098108)']},
#  '1489378169': {'polygon': ['(416559.033477, 4730871.541563)',
#    '(416557.391321, 4730871.782440)',
#    '(416554.095427, 4730869.755178)',
#    '(416568.629142, 4730846.463015)',
#    '(416569.373527, 4730846.442896)',
#    '(416570.047884, 4730845.274354)',
#    '(416569.594545, 4730844.947118)',
#    '(416583.866015, 4730821.329971)',
#    '(416586.966897, 4730823.304376)',
#    '(416587.748728, 4730825.613560)',
#    '(416578.513180, 4730839.956254)',
#    '(416573.916341, 4730847.630050)',
#    '(416573.335491, 4730847.231872)',
#    '(416572.483501, 4730848.479690)',
#    '(416573.039802, 4730849.127242)',
#    '(416566.811637, 4730858.686605)',
#    '(416563.275629, 4730864.368556)']},
#  '1489378170': {'polygon': ['(416524.887239, 4730853.816423)',
#    '(416522.008801, 4730852.018807)',
# ...
